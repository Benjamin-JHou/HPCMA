# %% [markdown]
# # Tutorial 4: Causal Gene Prioritization (Step 3)
#
# Master Mendelian Randomization and colocalization analysis.
#
# ## Learning Objectives
#
# 1. MR instrument selection criteria
# 2. Multiple MR methods comparison
# 3. Sensitivity analyses
# 4. Colocalization interpretation
# 5. Evidence integration for gene prioritization
