# %% [markdown]
# # Tutorial 3: Genetic Architecture Analysis (Step 2)
#
# Learn how to compute genetic correlations and analyze shared architecture.
#
# ## Topics
#
# 1. LD Score Regression theory
# 2. Genetic correlation estimation
# 3. Cross-trait meta-analysis
# 4. Visualization of genetic correlations
