# %% [markdown]
# # Tutorial 5: Cell-Type Mapping (Step 4)
#
# Explore single-cell transcriptomics integration.
#
# ## Topics
#
# 1. Single-cell atlas data access
# 2. Cell-type specificity scoring
# 3. Tau calculation
# 4. Mechanism axis assignment
# 5. Disease-relevant cell identification
